# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
#Thomas Scott
#Python Pandas Homework
#Due Date: 5-15-2021

# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

#imported later for heatmaps
import seaborn as sns

# %matplotlib inline

#Might not be necesary, but adding anyway just in case I need it
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
Whale_Returns = Path('Resources/whale_returns.csv')

Algo_Returns = Path('Resources/algo_returns.csv')

SP500_History = Path('Resources/sp500_history.csv')

Whale_df = pd.read_csv(Whale_Returns)

# %%
# Count nulls
Whale_df.isnull()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# ...

# %%
#Sort the index using a built-in function
Whale_df.sort_index()
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     2015-03-02                        NaN                 NaN
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                             NaN                     NaN
# 1                       -0.000496               -0.006569
# ...

# %%
# Drop nulls
Whale_df.dropna()
# Out:
#             Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 1     2015-03-03                  -0.001266           -0.004981
# 2     2015-03-04                   0.002230            0.003241
# 3     2015-03-05                   0.004016            0.004076
# 4     2015-03-06                  -0.007905           -0.003574
# 5     2015-03-09                   0.000582            0.004225
# ...          ...                        ...                 ...
# 1055  2019-04-25                  -0.000285           -0.001291
# 1056  2019-04-26                   0.008149            0.009162
# 1057  2019-04-29                   0.001254            0.002719
# 1058  2019-04-30                  -0.001295           -0.002211
# 1059  2019-05-01                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 1                       -0.000496               -0.006569
# 2                       -0.002534                0.004213
# ...

# %%
#Recount the null values in the 'Whale' dataframe
Whale_df.isna()
# Out:
#        Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0     False                       True                True
# 1     False                      False               False
# 2     False                      False               False
# 3     False                      False               False
# 4     False                      False               False
# ...     ...                        ...                 ...
# 1055  False                      False               False
# 1056  False                      False               False
# 1057  False                      False               False
# 1058  False                      False               False
# 1059  False                      False               False
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                            True                    True
# 1                           False                   False
# 2                           False                   False
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
Algo_df = pd.read_csv(Algo_Returns)
Algo_df
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
# Count nulls
Algo_df.isna()
# Out:
#        Date  Algo 1  Algo 2
# 0     False   False    True
# 1     False   False    True
# 2     False   False    True
# 3     False   False    True
# 4     False   False    True
# ...     ...     ...     ...
# 1236  False   False   False
# 1237  False   False   False
# 1238  False   False   False
# 1239  False   False   False
# 1240  False   False   False
#
# [1241 rows x 3 columns]

# %%
#Sort the index using a built-in function
Algo_df.sort_index()
# Out:
#             Date    Algo 1    Algo 2
# 0     2014-05-28  0.001745       NaN
# 1     2014-05-29  0.003978       NaN
# 2     2014-05-30  0.004464       NaN
# 3     2014-06-02  0.005692       NaN
# 4     2014-06-03  0.005292       NaN
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1241 rows x 3 columns]

# %%
# Drop nulls
Algo_df.dropna()
# Out:
#             Date    Algo 1    Algo 2
# 6     2014-06-05  0.004062  0.013285
# 7     2014-06-06  0.001857  0.008284
# 8     2014-06-09 -0.005012  0.005668
# 9     2014-06-10  0.004406 -0.000735
# 10    2014-06-11  0.004760 -0.003761
# ...          ...       ...       ...
# 1236  2019-04-25  0.000682 -0.007247
# 1237  2019-04-26  0.002981  0.005256
# 1238  2019-04-29  0.005208  0.002829
# 1239  2019-04-30 -0.002944 -0.001570
# 1240  2019-05-01  0.000094 -0.007358
#
# [1235 rows x 3 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
SP500_df = pd.read_csv(SP500_History)
SP500_df
# Out:
#            Date     Close
# 0     23-Apr-19  $2933.68
# 1     22-Apr-19  $2907.97
# 2     18-Apr-19  $2905.03
# 3     17-Apr-19  $2900.45
# 4     16-Apr-19  $2907.06
# ...         ...       ...
# 1644   5-Oct-12  $1460.93
# 1645   4-Oct-12  $1461.40
# 1646   3-Oct-12  $1450.99
# 1647   2-Oct-12  $1445.75
# 1648   1-Oct-12  $1444.49
#
# [1649 rows x 2 columns]

# %%
# Check Data Types
SP500_df.dtypes.value_counts()
# Out:
# object    2
# dtype: int64

# %%
# Fix Data Types

#Convert values in 'Date' column to datetime format
SP500_DateTime =  pd.to_datetime(SP500_df['Date'])
SP500_DateTime
# Out:
# 0      2019-04-23
# 1      2019-04-22
# 2      2019-04-18
# 3      2019-04-17
# 4      2019-04-16
#           ...
# 1644   2012-10-05
# 1645   2012-10-04
# 1646   2012-10-03
# 1647   2012-10-02
# 1648   2012-10-01
# Name: Date, Length: 1649, dtype: datetime64[ns]

# %%
#Remove currency symbol from 'close column'
SP500_currency_removal = pd.to_numeric(SP500_df['Close'].str.replace('$', ''))
SP500_currency_removal
# Out:
# 0       2933.68
# 1       2907.97
# 2       2905.03
# 3       2900.45
# 4       2907.06
#          ...
# 1644    1460.93
# 1645    1461.40
# 1646    1450.99
# 1647    1445.75
# 1648    1444.49
# Name: Close, Length: 1649, dtype: float64

# %%
#Concatinate two dataframes and reset the index & drop null values
SP_500_New_df = pd.concat([SP500_DateTime, SP500_currency_removal], axis = 1).dropna()
SP_500_New_df
# Out:
#            Date    Close
# 0    2019-04-23  2933.68
# 1    2019-04-22  2907.97
# 2    2019-04-18  2905.03
# 3    2019-04-17  2900.45
# 4    2019-04-16  2907.06
# ...         ...      ...
# 1644 2012-10-05  1460.93
# 1645 2012-10-04  1461.40
# 1646 2012-10-03  1450.99
# 1647 2012-10-02  1445.75
# 1648 2012-10-01  1444.49
#
# [1649 rows x 2 columns]

# %%
#Sort index using built in function
SP_500_New_df.sort_index()
# Out:
#            Date    Close
# 0    2019-04-23  2933.68
# 1    2019-04-22  2907.97
# 2    2019-04-18  2905.03
# 3    2019-04-17  2900.45
# 4    2019-04-16  2907.06
# ...         ...      ...
# 1644 2012-10-05  1460.93
# 1645 2012-10-04  1461.40
# 1646 2012-10-03  1450.99
# 1647 2012-10-02  1445.75
# 1648 2012-10-01  1444.49
#
# [1649 rows x 2 columns]

# %%
# Calculate Daily Returns
SP_500_New_df['Close'].pct_change()
# Out:
# 0            NaN
# 1      -0.008764
# 2      -0.001011
# 3      -0.001577
# 4       0.002279
#           ...
# 1644    0.003469
# 1645    0.000322
# 1646   -0.007123
# 1647   -0.003611
# 1648   -0.000872
# Name: Close, Length: 1649, dtype: float64

# %%
#Plot daily returns to check result
SP_500_Returns = SP_500_New_df['Close'].pct_change()
SP_500_Returns
# Out:
# 0            NaN
# 1      -0.008764
# 2      -0.001011
# 3      -0.001577
# 4       0.002279
#           ...
# 1644    0.003469
# 1645    0.000322
# 1646   -0.007123
# 1647   -0.003611
# 1648   -0.000872
# Name: Close, Length: 1649, dtype: float64

# %%
# Rename `Close` Column to be specific to this portfolio.

SP_500_New_Returns_df = pd.concat([SP500_DateTime, SP_500_Returns], axis = 1).dropna()
SP_500_New_Returns_df.rename(columns = {'Close': 'S&P 500'}, inplace = True)
SP_500_New_Returns_df
# Out:
#            Date   S&P 500
# 1    2019-04-22 -0.008764
# 2    2019-04-18 -0.001011
# 3    2019-04-17 -0.001577
# 4    2019-04-16  0.002279
# 5    2019-04-15 -0.000509
# ...         ...       ...
# 1644 2012-10-05  0.003469
# 1645 2012-10-04  0.000322
# 1646 2012-10-03 -0.007123
# 1647 2012-10-02 -0.003611
# 1648 2012-10-01 -0.000872
#
# [1648 rows x 2 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

#Ensure that duplicative 'Date' columns are dropped from the final dataframe & drop nulls
Combined_Portfolio_Returns_df = pd.concat([Whale_df.drop(columns='Date'), Algo_df.drop(columns='Date'), SP_500_New_Returns_df.drop(columns='Date')], axis = 1).dropna()

#Reset index and drop duplicate 'index' column
Combined_Portfolio_Returns_Fixed = Combined_Portfolio_Returns_df.reset_index().drop(columns='index')

#View the data to ensure quality
Combined_Portfolio_Returns_Fixed
# Out:
#       SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0                     -0.010263           -0.005341
# 1                      0.004012            0.005163
# 2                      0.008265            0.010272
# 3                     -0.002497           -0.001428
# 4                      0.007901            0.003583
# ...                         ...                 ...
# 1049                  -0.000285           -0.001291
# 1050                   0.008149            0.009162
# 1051                   0.001254            0.002719
# 1052                  -0.001295           -0.002211
# 1053                  -0.005847           -0.001341
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# 0                       -0.012079               -0.009739  0.004062  0.013285
# 1                        0.003312               -0.001147  0.001857  0.008284
# 2                        0.013117                0.010801 -0.005012  0.005668
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
#The visual looks a bit messy, but is an accurate depiction of the data.
Combined_Portfolio_Returns_Fixed.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
Cumulative_Returns = (1 + Combined_Portfolio_Returns_Fixed ).cumprod() - 1

# Plot cumulative returns
Cumulative_Returns.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
Cumulative_Returns.boxplot(figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
Cumulative_Returns.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.074000
# PAULSON & CO.INC.              0.087924
# TIGER GLOBAL MANAGEMENT LLC    0.151558
# BERKSHIRE HATHAWAY INC         0.245659
# Algo 1                         0.231788
# Algo 2                         0.149885
# S&P 500                        0.104526
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
Cumulative_Returns['S&P 500'].std()
# Out:
# 0.10452598964457513

# %%
# Determine which portfolios are riskier than the S&P 500

#Use a for loop to iterate through dataset and compare standard deviations in all other portfolios to the S&P 500
for x in Cumulative_Returns:
    if Cumulative_Returns[x].std()  > Cumulative_Returns['S&P 500'].std():
        print(f"{x} is riskier than S&P 500")
# Out:
# TIGER GLOBAL MANAGEMENT LLC is riskier than S&P 500
# BERKSHIRE HATHAWAY INC is riskier than S&P 500
# Algo 1 is riskier than S&P 500
# Algo 2 is riskier than S&P 500

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

#The following code is based on Tobin's formula for standard deviations which I found on Google and requires Numpy.

Variation = Cumulative_Returns.var()
Mean = Variation.mean() + 1
Annualized_std_dev = np.sqrt(((Variation + (Mean**2))**12) - Mean**24)
Annualized_std_dev
# Out:
# SOROS FUND MANAGEMENT LLC      0.345750
# PAULSON & CO.INC.              0.413253
# TIGER GLOBAL MANAGEMENT LLC    0.741744
# BERKSHIRE HATHAWAY INC         1.331023
# Algo 1                         1.233137
# Algo 2                         0.732565
# S&P 500                        0.495441
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P 500 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

Rolling_Avg = Cumulative_Returns.rolling(window = 21).mean()

# Plot the rolling standard deviation
Rolling_Avg.plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
Correlation = Cumulative_Returns.corr()

# Display the correlation matrix
#I had to go back and import seaborn for this

sns.heatmap(Correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
#I calculated the S&P variance against Berkshire Hathawaay just because cov requires 2 elements for contrast.
Covariance = Cumulative_Returns['S&P 500'].cov(Cumulative_Returns['BERKSHIRE HATHAWAY INC'])
print(f"Covariance between S&P 500 and Berkshire Hathaway: {Covariance}\n")

# Calculate variance of S&P 500
Variance = Cumulative_Returns['S&P 500'].var()
print(f"Variance of S&P 500: {Variance}\n")

# Calculate beta

Beta = Covariance / Variance

print(f"The Beta for S&P 500 is: {Beta}\n")

# Plot beta trend
#First you have to calculate the rolling covariance & variance

Rolling_Cov = Combined_Portfolio_Returns_Fixed['S&P 500'].rolling(window = 30).cov(Combined_Portfolio_Returns_Fixed['BERKSHIRE HATHAWAY INC'])
Rolling_Cov.plot()
# Out:
# Covariance between S&P 500 and Berkshire Hathaway: -0.0224936107330884
#
# Variance of S&P 500: 0.010925682511177828
#
# The Beta for S&P 500 is: -2.0587831204206855
# <AxesSubplot:>

# %%
#Calculate variance separately
Rolling_Var = Cumulative_Returns['S&P 500'].rolling(window = 30).var()

#Plot the variance
Rolling_Var.plot()
# Out:
# <AxesSubplot:>

# %%
#Calculate the rolling beta and assign the results to its own variable
Rolling_Beta = Rolling_Cov / Rolling_Var

#Plot lot the trend, set the size of the visual and give it a title
Rolling_Beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta of S&P 500')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of S&P 500'}>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
Exp_Weighted_Avg = Cumulative_Returns.ewm(halflife = 21)
Exp_Weighted_Avg.mean()
# Out:
#       SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0                     -0.010263           -0.005341
# 1                     -0.008245           -0.002731
# 2                     -0.004744            0.001676
# 3                     -0.003651            0.003499
# 4                     -0.001311            0.005364
# ...                         ...                 ...
# 1049                   0.124268           -0.224671
# 1050                   0.126052           -0.224381
# 1051                   0.127826           -0.224031
# 1052                   0.129493           -0.223750
# 1053                   0.130882           -0.223511
#
#       TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# 0                       -0.012079               -0.009739  0.004062  0.013285
# 1                       -0.010416               -0.010316  0.005010  0.017551
# 2                       -0.005385               -0.006829  0.003589  0.020967
# ...

# %%
#Plot EWM
Plot_Exp_Mv_Avg = Exp_Weighted_Avg.mean()
Plot_Exp_Mv_Avg.plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
Sharpe_Ratio = (Annualized_std_dev.mean() * 252) / (Annualized_std_dev * np.sqrt(252))
Sharpe_Ratio.head()
# Out:
# SOROS FUND MANAGEMENT LLC      34.716435
# PAULSON & CO.INC.              29.045640
# TIGER GLOBAL MANAGEMENT LLC    16.182389
# BERKSHIRE HATHAWAY INC          9.018025
# Algo 1                          9.733874
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
Sharpe_Ratio.plot.bar(title='Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# While the Algorithms outperformed the S&P 500, they could not beat the Oracle of Omaha i.e the great Warren Buffet. Berkshire Hathaway clearly has a lower risk profile than both algorithmic portfolios. There is hope for humanity yet.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock
CSGP_Returns = Path('Resources/CSGP.csv')

# %%
# Reading data from 2nd stock
BOKF_Returns = Path('Resources/BOKF.csv')

# %%
# Reading data from 3rd stock
M_Returns = Path('Resources/M.csv')

# %%
# Combine all stocks in a single DataFrame & reorganize portfolio data by having a column per symbol)

CSGP_df = pd.read_csv(CSGP_Returns)
CSGP_df.rename(columns = {'Close': 'CoStar Group'}, inplace = True)

#Sort index
CSGP_df.sort_index()

BOKF_df = pd.read_csv(BOKF_Returns)
BOKF_df.rename(columns = {'Close': 'Bank of Oklahoma'}, inplace = True)

#Sort index
BOKF_df.sort_index()

M_df = pd.read_csv(M_Returns)
M_df.rename(columns = {'Close': 'Macys'}, inplace = True)

#Sort index
M_df.sort_index()

Second_Portfolio = pd.concat([CSGP_df, BOKF_df.drop(columns='Date'), M_df.drop(columns='Date')], axis = 1).dropna()
Second_Portfolio
# Out:
#             Date  CoStar Group  Bank of Oklahoma  Macys
# 0      3/3/2015         198.14             59.26  63.47
# 1      3/4/2015         194.61             58.88  62.89
# 2      3/5/2015         193.69             59.10  63.19
# 3      3/6/2015         192.14             59.72  62.98
# 4      3/9/2015         192.47             60.81  62.56
# ...          ...           ...               ...    ...
# 1043  4/24/2019         474.37             86.16  25.05
# 1044  4/25/2019         486.10             85.77  24.13
# 1045  4/26/2019         488.13             86.90  24.26
# 1046  4/29/2019         489.30             88.05  24.09
# 1047  4/30/2019         496.25             87.14  23.54
#
# [1048 rows x 4 columns]

# %%
# Reset Date index and remove duplicate index column
Second_Portfolio_Reset_Index = Second_Portfolio.reset_index().drop(columns='index')
Second_Portfolio_Reset_Index
# Out:
#             Date  CoStar Group  Bank of Oklahoma  Macys
# 0      3/3/2015         198.14             59.26  63.47
# 1      3/4/2015         194.61             58.88  62.89
# 2      3/5/2015         193.69             59.10  63.19
# 3      3/6/2015         192.14             59.72  62.98
# 4      3/9/2015         192.47             60.81  62.56
# ...          ...           ...               ...    ...
# 1043  4/24/2019         474.37             86.16  25.05
# 1044  4/25/2019         486.10             85.77  24.13
# 1045  4/26/2019         488.13             86.90  24.26
# 1046  4/29/2019         489.30             88.05  24.09
# 1047  4/30/2019         496.25             87.14  23.54
#
# [1048 rows x 4 columns]

# %%
# Reorganize portfolio data by having a column per symbol
#Already complete, see above

# %%
# Calculate daily returns & drop NAs
Second_Portfolio_DateTime = pd.to_datetime(Second_Portfolio_Reset_Index['Date'])
CSGP_Daily_Returns = Second_Portfolio_Reset_Index['CoStar Group'].pct_change().dropna()
BOKF_Daily_Returns = Second_Portfolio_Reset_Index['Bank of Oklahoma'].pct_change().dropna()
M_Daily_Returns = Second_Portfolio_Reset_Index['Macys'].pct_change().dropna()

Second_Portfolio_Daily_Returns = pd.concat([Second_Portfolio_Dates, CSGP_Daily_Returns,BOKF_Daily_Returns, M_Daily_Returns], axis = 1).dropna().reset_index().drop(columns = 'index')

# Display sample data
Second_Portfolio_Daily_Returns.head()
# Out:
#         Date  CoStar Group  Bank of Oklahoma     Macys
# 0 2020-05-15     -0.017816         -0.006412 -0.009138
# 1 2020-05-18     -0.004727          0.003736  0.004770
# 2 2020-05-19     -0.008002          0.010491 -0.003323
# 3 2020-05-20      0.001717          0.018252 -0.006669
# 4 2020-05-21     -0.008053         -0.010689  0.011829

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

#Remove date column to prevent shape error
Weighted_Portfolio = Second_Portfolio_Daily_Returns.drop(columns = 'Date')

# Calculate portfolio return
Weighted_Returns = Weighted_Portfolio.dot(weights)

#Add back the date column
Numerical_Date_Column = pd.to_datetime(Second_Portfolio_Daily_Returns['Date'])
Weighted_Returns_With_Date_Column = pd.concat([Numerical_Date_Column, Weighted_Returns], axis = 1).dropna().reset_index()

#Remove the extra index column by 'spliting' it from the datafram
Split_Weighted_Returns = Weighted_Returns_With_Date_Column.drop(columns = 'index')

# Display sample data
Split_Weighted_Returns = Split_Weighted_Returns.rename(columns = {0: 'Weighted'})
Split_Weighted_Returns.head()
# Out:
#         Date  Weighted
# 0 2020-05-15 -0.011122
# 1 2020-05-18  0.001260
# 2 2020-05-19 -0.000278
# 3 2020-05-20  0.004434
# 4 2020-05-21 -0.002305

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

Final_Portfolio = pd.concat([Whale_df.drop(columns = 'Date'), Algo_df.drop(columns = 'Date'), SP_500_New_Returns_df.drop(columns = 'Date'), Split_Weighted_Returns.drop(columns = 'Date')], axis = 1).dropna().reset_index()
Final_Portfolio
# Out:
#      index  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0        6                  -0.010263           -0.005341
# 1        7                   0.004012            0.005163
# 2        8                   0.008265            0.010272
# 3        9                  -0.002497           -0.001428
# 4       10                   0.007901            0.003583
# ..     ...                        ...                 ...
# 240    246                   0.000000            0.000000
# 241    247                   0.021759            0.013463
# 242    248                   0.019218            0.016534
# 243    249                  -0.003321           -0.011458
# 244    250                   0.001313           -0.003753
#
#      TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# 0                      -0.012079               -0.009739  0.004062  0.013285
# 1                       0.003312               -0.001147  0.001857  0.008284
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
Last_Portfolio = Final_Portfolio.dropna()

#Drop duplicate index column

Final_Portfolio = Last_Portfolio.drop(columns = 'index')

#Display sample data
Final_Portfolio.head()
# Out:
#    SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# 0                  -0.010263           -0.005341                    -0.012079
# 1                   0.004012            0.005163                     0.003312
# 2                   0.008265            0.010272                     0.013117
# 3                  -0.002497           -0.001428                    -0.003697
# 4                   0.007901            0.003583                     0.007953
#
#    BERKSHIRE HATHAWAY INC    Algo 1    Algo 2   S&P 500  Weighted
# 0               -0.009739  0.004062  0.013285  0.000630  0.009940
# 1               -0.001147  0.001857  0.008284 -0.006566 -0.001830
# 2                0.010801 -0.005012  0.005668 -0.000038  0.011187
# 3               -0.008142  0.004406 -0.000735 -0.003466  0.003277
# 4                0.008055  0.004760 -0.003761  0.006105  0.002921

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
Final_Portfolio_Std_Dev = Final_Portfolio.std()
Final_Portfolio_Std_Dev
# Out:
# SOROS FUND MANAGEMENT LLC      0.008800
# PAULSON & CO.INC.              0.006308
# TIGER GLOBAL MANAGEMENT LLC    0.009363
# BERKSHIRE HATHAWAY INC         0.014900
# Algo 1                         0.009111
# Algo 2                         0.008513
# S&P 500                        0.009533
# Weighted                       0.013788
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
Final_Rolling_Avg = Final_Portfolio.rolling(window = 21).mean()

# Plot rolling standard deviation
Final_Rolling_Avg.plot(figsize = (10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
Final_Correlation = Final_Rolling_Avg.corr()

sns.heatmap(Final_Correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
Final_Covariance = Final_Portfolio['Weighted'].cov(Final_Portfolio['S&P 500'])
print(f"Covariance between the weighted portion of the portfolio and the S&P 500 is: {Final_Covariance}\n")

# Calculate variance of S&P 500
Final_Variance = Final_Portfolio['S&P 500'].var()
print(f"Variance of S&P 500 compared to the overall portfolio is: {Final_Variance}\n")

# Compute the beta

Final_Beta = Final_Covariance / Final_Variance

print(f"The Beta is: {Final_Beta}\n")

#Plot the Beta
Final_Rolling_Cov = Final_Portfolio['S&P 500'].rolling(window = 60).cov(Final_Portfolio['Weighted'])
Final_Rolling_Cov.plot()
# Out:
# Covariance between the weighted portion of the portfolio and the S&P 500 is: 5.793230676515679e-06
#
# Variance of S&P 500 compared to the overall portfolio is: 9.088160114126108e-05
#
# The Beta is: 0.0637448130729015
# <AxesSubplot:>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios & display data
Final_Sharpe_Ratio = (Final_Portfolio_Std_Dev.mean() * 252) / (Final_Portfolio_Std_Dev * np.sqrt(252))
Final_Sharpe_Ratio
# Out:
# SOROS FUND MANAGEMENT LLC      18.111501
# PAULSON & CO.INC.              25.264330
# TIGER GLOBAL MANAGEMENT LLC    17.021431
# BERKSHIRE HATHAWAY INC         10.696012
# Algo 1                         17.491983
# Algo 2                         18.721513
# S&P 500                        16.717875
# Weighted                       11.558611
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
Final_Sharpe_Ratio.plot.bar(title='Weighted Portfolio Sharpe Ratios')
# Out:
# <AxesSubplot:title={'center':'Weighted Portfolio Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
#The weighted portfolio did remarkably well. I picked three stocks that were in three sectors of the economy. The first was CoStar,
#which was a technology company I used to work for that is considered a "growth stock" do to its buying spree and deployment
#of software solutions for the real-estate sector. The second was a financial institution called Bank of Oklahoma, where I worked in
#their mortgage lending unit. The third, of course, is Macy's the nation-wide retailer with whom I bought several shares recently. Per our
#class on Sharpe Ratios I looked for "relatively" unrelated stocks for diversification purposes. The results speak for themselves. Based on the 
#bar graph, my sharpe ratios are second only to Berkshire Hathaway. However, performance is an area of concern given that the Beta graph dipped
#markedly once I added my weighted basked of stocks. The heat map also puts the weighted basket behind algorithmic funds 1 & 2 as well as the S&P 500. 
#A key takeaway here is that just because the portfolio is diverse per se, doesn't mean the assets picked will yield a high return. 
#Stick with the professionals & their new robotic friends!
